# %%
import pandas as pd
from pathlib import Path

BASE_DIR = Path.cwd().parent.parent.parent
DATA_RAW = BASE_DIR / "data" / "raw"
DATA_PROCESSED = BASE_DIR / "data" / "processed"

# %%
def normalize_event_type(x):
    x = str(x).lower()

    if "release" in x:
        return "Release"
    if "trailer" in x or "screenshot" in x or "gameplay" in x or "reveal" in x:
        return "Trailer/Reveal"
    if "delay" in x:
        return "Delay"
    if "acquisition" in x or "m&a" in x or "codemasters" in x or "zynga" in x:
        return "Corporate Event"
    if "earn" in x:
        return "Earnings"
    if "lawsuit" in x or "scandal" in x or "controversy" in x:
        return "Controversy"
    if "leak" in x:
        return "Leak"
    if "hype" in x or "announce" in x or "confirm" in x:
        return "Major Announcement"
    return "Other"
    

events["event_type"] = events["event_type"].apply(normalize_event_type)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 23
#      19         return "Major Announcement"
#      20     return "Other"
# ---> 23 events["event_type"] = events["event_type"].apply(normalize_event_type)
#
# NameError: name 'events' is not defined
