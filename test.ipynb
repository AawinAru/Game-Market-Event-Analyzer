# %%
# Test pytrends installation
print("Testing pytrends installation...\n")

try:
    from pytrends.request import TrendReq
    print("✅ Import successful: pytrends.request.TrendReq")
except ImportError as e:
    print(f"❌ Import failed: {e}")
    exit()

# Initialize client
try:
    gt = TrendReq(hl='en-US', tz=360)
    print("✅ TrendReq client initialized")
except Exception as e:
    print(f"❌ Client initialization failed: {e}")
    exit()

# Test: Query a simple trend (GTA VI)
try:
    print("\n🔍 Querying Google Trends for 'GTA VI'...")
    gt.build_payload(['GTA VI'], timeframe='today 1-m')
    data = gt.interest_over_time()
    print("✅ Query successful!")
    print(f"\nData shape: {data.shape}")
    print(f"Columns: {data.columns.tolist()}")
    print(f"\nFirst 5 rows:")
    print(data.head())
except Exception as e:
    print(f"❌ Query failed: {e}")
    exit()

print("\n" + "="*80)
print("✅ PYTRENDS IS WORKING CORRECTLY!")
print("="*80)
# Out:
# Testing pytrends installation...
#
# ✅ Import successful: pytrends.request.TrendReq
# ✅ TrendReq client initialized
#
# 🔍 Querying Google Trends for 'GTA VI'...
# ✅ Query successful!
#
# Data shape: (31, 2)
# Columns: ['GTA VI', 'isPartial']
#
# First 5 rows:
#             GTA VI  isPartial
# date
# 2025-11-16      79      False
# 2025-11-17      76      False
# 2025-11-18      78      False
# 2025-11-19      78      False
# 2025-11-20      81      False
#
# ================================================================================
# ✅ PYTRENDS IS WORKING CORRECTLY!
# ================================================================================
# /files/.venv/lib/python3.12/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
